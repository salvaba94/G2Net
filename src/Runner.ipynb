# %%
gpu_info = !nvidia-smi
gpu_info = "\n".join(gpu_info)
if gpu_info.find("failed") >= 0:
  print("GPU execution environment is not activated.")
else:
  print(gpu_info)
# Out:
# Thu Aug 26 18:56:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install tensorflow-addons
# !pip install adabelief-tf
# Out:
# ...
#      |████████████████████████████████| 1.1 MB 7.7 MB/s
# ...

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !mkdir -p G2Net
# !unzip /content/gdrive/MyDrive/data.zip -d /content/G2Net
# !unzip /content/gdrive/MyDrive/G2Net.zip -d /content/G2Net
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: /content/G2Net/data/train/fdc9472200.npy
#   inflating: /content/G2Net/data/train/fdc9f1d14f.npy
#   inflating: /content/G2Net/data/train/fdca15537a.npy
#   inflating: /content/G2Net/data/train/fdca45d01f.npy
#   inflating: /content/G2Net/data/train/fdca9e1178.npy
#   inflating: /content/G2Net/data/train/fdcab7ea52.npy
#   inflating: /content/G2Net/data/train/fdcaba5473.npy
#   inflating: /content/G2Net/data/train/fdcac76902.npy
#   inflating: /content/G2Net/data/train/fdcad475e0.npy
#   inflating: /content/G2Net/data/train/fdcaecab0d.npy
#   inflating: /content/G2Net/data/train/fdcb1bb265.npy
#   inflating: /content/G2Net/data/train/fdcb95606e.npy
#   inflating: /content/G2Net/data/train/fdcc0f1188.npy
#   inflating: /content/G2Net/data/train/fdcc4d78ae.npy
#   inflating: /content/G2Net/data/train/fdcc6cb567.npy
#   inflating: /content/G2Net/data/train/fdcc87c2b9.npy
# ...

# %%
# %cd /content/G2Net/src
# !pwd
# Out:
# /content/G2Net/src
# /content/G2Net/src

# %%
# !python main.py
# Out:
# 2021-08-26 19:33:44.022881: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 19:33:44.031714: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 19:33:44.032920: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 19:33:44.642340: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !cp -r /content/G2Net/cqt_data/submission.csv /content/gdrive/MyDrive/
# !cp -r /content/G2Net/checkpoint /content/gdrive/MyDrive/
# !cp -r /content/G2Net/saved_models* /content/gdrive/MyDrive/
drive.flush_and_unmount()
# Out:
# cp: cannot stat '/content/G2Net/cqt_data/submission.csv': No such file or directory
# cp: cannot stat '/content/G2Net/checkpoint': No such file or directory
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-44198af297f7> in <module>()
#       2 get_ipython().system('cp -r /content/G2Net/checkpoint /content/gdrive/MyDrive/')
#       3 get_ipython().system('cp -r /content/G2Net/saved_models* /content/gdrive/MyDrive/')
# ----> 4 drive.flush_and_unmount()
#
# NameError: name 'drive' is not defined
